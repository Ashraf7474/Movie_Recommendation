# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from time import sleep
from random import randint

# %%
# import requests
# from bs4 import BeautifulSoup
# import pandas as pd

# headers={
#   "User-Agent" : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36 Edg/110.0.1587.50'
# }

# movie_name = []
# certificate = []
# year = []
# time = []
# genre = []
# rating = []
# metascore = []
# votes = []
# gross = []

# for page in range(1, 50):  # Change the range to the desired number of pages
#     url = f"https://www.imdb.com/list/ls063676189/?sort=list_order,asc&st_dt=&mode=detail&page={page}"

#     response = requests.get(url, headers=headers)
#     soup = BeautifulSoup(response.content, 'html.parser')
#     movie_data = soup.find_all("div", attrs={"class": "lister-item mode-detail"})

#     for store in movie_data:
        
#         Images=
        
        
        
#         name = store.h3.a.text
#         movie_name.append(name)

#         year_of_release = store.h3.find('span', class_='lister-item-year text-muted unbold').text.strip('()')
#         year.append(year_of_release)

#         movie_certificate = store.p.find('span', class_='certificate').text
#         certificate.append(movie_certificate)

#         runtime = store.p.find('span', class_='runtime').text.replace(' min', '')
#         time.append(runtime)

#         genre_text = store.p.find('span', class_='genre').text.strip()
#         genre.append(genre_text)

#         rate = store.find('span', class_ = 'ipl-rating-star__rating').text
#         rating.append(rate)

#         meta = store.find('span', class_='metascore')
#         metascore.append(meta.text.strip() if meta else '^^^^^^')

#         # Since, gross and votes have the same attributes, we create a common variable and then use indexing
#         value = store.find_all('span', attrs={'name': 'nv'})

#         vote = value[0].text
#         votes.append(vote)

#         grosses = value[1].text if len(value) > 1 else '*****'
#         gross.append(grosses)

# # Create a DataFrame using the collected data
# movie_DF = pd.DataFrame({
#     'Image':photo
#     'Name of movie': movie_name,
#     'Year of release': year,
#     'Certificate': certificate,
#     'Runtime (min)': time,
#     'Genre': genre,
#     'Rating': rating,
#     'MetaScore': metascore,
#     'Votes': votes,
#     'Grosses': gross
# })

# # Print the DataFrame
# movie_DF

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

headers = {
    "User-Agent": 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36 Edg/110.0.1587.50'
}

movie_name = []
certificate = []
year = []
time = []
genre = []
rating = []
metascore = []
votes = []
gross = []
image_links = []
descrides = []
casts = []

for page in range(1, 50):  # Change the range to the desired number of pages
    url = f"https://www.imdb.com/list/ls063676660/?sort=list_order,asc&st_dt=&mode=detail&page={page}"

    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')
    movie_data = soup.find_all("div", attrs={"class": "lister-item mode-detail"})

    for store in movie_data:
        # Extract the image link from the 'data-tconst' attribute of the 'img' tag
        img_tag = store.find('img', class_='loadlate')
        if img_tag:
            image_link = img_tag.get('loadlate')
            image_links.append(image_link)

        name = store.h3.a.text
        movie_name.append(name)

        year_of_release = store.h3.find('span', class_='lister-item-year text-muted unbold').text.strip('()')
        year.append(year_of_release)

        # Check if the certificate element exists before accessing its .text attribute
        movie_certificate = store.p.find('span', class_='certificate')
        certificate.append(movie_certificate.text if movie_certificate else 'N/A')

        runtime = store.p.find('span', class_='runtime').text.replace(' min', '')
        time.append(runtime)

        genre_text = store.p.find('span', class_='genre').text.strip()
        genre.append(genre_text)

        rate = store.find('span', class_='ipl-rating-star__rating').text
        rating.append(rate)

        meta = store.find('span', class_='metascore')
        metascore.append(meta.text.strip() if meta else '^^^^^^')

        # Since gross and votes have the same attributes, we create a common variable and then use indexing
        value = store.find_all('span', attrs={'name': 'nv'})

        vote = value[0].text
        votes.append(vote)

        grosses = value[1].text if len(value) > 1 else '*****'
        gross.append(grosses)

        # Extract the description from the 'p' tag
        desc = store.find("p", class_='')
        desc = desc.text.replace('\n', '').split('|')
        descr = '|'.join([x.strip() for x in desc])
        descrides.append(descr)

        # Extract the cast details
        
        cast = store.find_all('p', class_ = 'text-muted')
        castts = cast[1].text.replace('\n', '') if len(describe) >1 else '*****'
        casts.append(castts)


# Create a DataFrame using the collected data
movie_df = pd.DataFrame({
    'Image Link': image_links,
    'Name of movie': movie_name,
    'Year of release': year,
    'Certificate': certificate,
    'Runtime (min)': time,
    'Genre': genre,
    'Rating': rating,
    'MetaScore': metascore,
    'Votes': votes,
    'Grosses': gross,
    'Description': descrides,
    'Casts': casts
})
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16816\112908821.py in <module>
#      69         cast = cast.text.replace('\n', '').split('|')
#      70         cast = [x.strip() for x in cast]
# ---> 71         cast = [cast[i].replace(j, "") for i,j in enumerate(["Director:", "Stars:"])]
#      72         Director.append(cast[0])
#      73         Stars.append([x.strip() for x in cast[1].split(",")])
#
# ~\AppData\Local\Temp\ipykernel_16816\112908821.py in <listcomp>(.0)
#      69         cast = cast.text.replace('\n', '').split('|')
#      70         cast = [x.strip() for x in cast]
# ---> 71         cast = [cast[i].replace(j, "") for i,j in enumerate(["Director:", "Stars:"])]
#      72         Director.append(cast[0])
#      73         Stars.append([x.strip() for x in cast[1].split(",")])
#
# IndexError: list index out of range

# %%
movie_df.to_excel('movie_data.xlsx', index=False)

print("DataFrame saved to 'movie_data.xlsx'")
# Out:
# DataFrame saved to 'movie_data.xlsx'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

headers = {
    "User-Agent": 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36 Edg/110.0.1587.50'
}

movie_name = []
certificate = []
year = []
time = []
genre = []
rating = []
metascore = []
votes = []
gross = []
image_links = []
descrides = []
casts = []

for page in range(1, 50):  # Change the range to the desired number of pages
    url = f"https://www.imdb.com/list/ls063676189/?sort=list_order,asc&st_dt=&mode=detail&page={page}"

    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')
    movie_data = soup.find_all("div", attrs={"class": "lister-item mode-detail"})

    for store in movie_data:
        # Extract the image link from the 'data-tconst' attribute of the 'img' tag
        img_tag = store.find('img', class_='loadlate')
        if img_tag:
            image_link = img_tag.get('loadlate')
            image_links.append(image_link)

        name = store.h3.a.text
        movie_name.append(name)

        year_of_release = store.h3.find('span', class_='lister-item-year text-muted unbold').text.strip('()')
        year.append(year_of_release)

        # Check if the certificate element exists before accessing its .text attribute
        movie_certificate = store.p.find('span', class_='certificate')
        certificate.append(movie_certificate.text if movie_certificate else 'N/A')

        runtime = store.p.find('span', class_='runtime').text.replace(' min', '')
        time.append(runtime)

        genre_text = store.p.find('span', class_='genre').text.strip()
        genre.append(genre_text)

        rate = store.find('span', class_='ipl-rating-star__rating').text
        rating.append(rate)

        meta = store.find('span', class_='metascore')
        metascore.append(meta.text.strip() if meta else '^^^^^^')

        # Since gross and votes have the same attributes, we create a common variable and then use indexing
        value = store.find_all('span', attrs={'name': 'nv'})

        vote = value[0].text
        votes.append(vote)

        grosses = value[1].text if len(value) > 1 else '*****'
        gross.append(grosses)

        # Extract the description from the 'p' tag
        desc = store.find("p", class_='')
        desc = desc.text.replace('\n', '').split('|')
        descr = '|'.join([x.strip() for x in desc])
        descrides.append(descr)

        # Extract the cast details
        
        cast = store.find_all('p', class_ = 'text-muted')
        castts = cast[1].text.replace('\n', '') if len(describe) >1 else '*****'
        casts.append(castts)


# Create a DataFrame using the collected data
movie_DF = pd.DataFrame({
    'Image Link': image_links,
    'Name of movie': movie_name,
    'Year of release': year,
    'Certificate': certificate,
    'Runtime (min)': time,
    'Genre': genre,
    'Rating': rating,
    'MetaScore': metascore,
    'Votes': votes,
    'Grosses': gross,
    'Description': descrides,
    'Casts': casts
})

# %%
movie_DF
# Out:
#                                              Image Link
# 0     https://m.media-amazon.com/images/M/MV5BNDE3OD...  \
# 1     https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 2     https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 3     https://m.media-amazon.com/images/M/MV5BODQ0OW...
# 4     https://m.media-amazon.com/images/M/MV5BNGNhMD...
# ...                                                 ...
# 4895  https://m.media-amazon.com/images/M/MV5BMmZiYj...
# 4896  https://m.media-amazon.com/images/M/MV5BYTQyZG...
# 4897  https://m.media-amazon.com/images/M/MV5BMjIwNj...
# 4898  https://m.media-amazon.com/images/M/MV5BMTk3NT...
# 4899  https://m.media-amazon.com/images/M/MV5BMTY3MD...
#
#                  Name of movie Year of release Certificate Runtime (min)
# 0     The Shawshank Redemption            1994           A           142  \
# 1              The Dark Knight            2008          UA           152
# 2                    Inception            2010          UA           148
# 3                   Fight Club            1999           A           139
# 4                 Pulp Fiction            1994           A           154
# ...                        ...             ...         ...           ...
# 4895            House of Games            1987           U           102
# 4896                Umberto D.            1952         N/A            89
# 4897                 The Women        I) (2008          UA           114
# 4898       Aliens in the Attic            2009           U            86
# 4899             The Promotion            2008           R            86
#
#                           Genre Rating MetaScore      Votes   Grosses
# 0                         Drama    9.3        82  2,797,507   $28.34M  \
# 1          Action, Crime, Drama      9        84  2,778,489  $534.86M
# 2     Action, Adventure, Sci-Fi    8.8        74  2,466,695  $292.58M
# 3                         Drama    8.8        67  2,231,343   $37.03M
# 4                  Crime, Drama    8.9        95  2,145,836  $107.93M
# ...                         ...    ...       ...        ...       ...
# 4895            Crime, Thriller    7.2        78     23,437    $2.59M
# 4896                      Drama    8.2        92     27,291    $0.07M
# 4897              Comedy, Drama      5        27     22,540   $26.90M
# 4898  Adventure, Comedy, Family    5.4        42     23,653   $25.20M
# 4899                     Comedy    5.6        51     19,360    $0.41M
#
#                                             Description
# 0     Over the course of several years, two convicts...  \
# 1     When the menace known as the Joker wreaks havo...
# 2     A thief who steals corporate secrets through t...
# 3     An insomniac office worker and a devil-may-car...
# 4     The lives of two mob hitmen, a boxer, a gangst...
# ...                                                 ...
# 4895  A psychiatrist comes to the aid of a compulsiv...
# 4896  An elderly man and his dog struggle to survive...
# 4897  A wealthy New Yorker wrestles with the decisio...
# 4898  A group of kids must protect their vacation ho...
# 4899  Two assistant managers of a corporate grocery ...
#
#                                                   Casts
# 0         Director:Frank Darabont|     Stars:Tim Rob...
# 1         Director:Christopher Nolan|     Stars:Chri...
# 2         Director:Christopher Nolan|     Stars:Leon...
# 3         Director:David Fincher|     Stars:Brad Pit...
# 4         Director:Quentin Tarantino|     Stars:John...
# ...                                                 ...
# 4895      Director:David Mamet|     Stars:Lindsay Cr...
# 4896      Director:Vittorio De Sica|     Stars:Carlo...
# 4897      Director:Diane English|     Stars:Meg Ryan...
# 4898      Director:John Schultz|     Stars:Ashley Ti...
# 4899      Director:Steve Conrad|     Stars:Seann Wil...
#
# [4900 rows x 12 columns]

# %%
movie_DF["Casts"]
# Out:
# 0           Director:Frank Darabont|     Stars:Tim Rob...
# 1           Director:Christopher Nolan|     Stars:Chri...
# 2           Director:Christopher Nolan|     Stars:Leon...
# 3           Director:David Fincher|     Stars:Brad Pit...
# 4           Director:Quentin Tarantino|     Stars:John...
#                               ...
# 4895        Director:David Mamet|     Stars:Lindsay Cr...
# 4896        Director:Vittorio De Sica|     Stars:Carlo...
# 4897        Director:Diane English|     Stars:Meg Ryan...
# 4898        Director:John Schultz|     Stars:Ashley Ti...
# 4899        Director:Steve Conrad|     Stars:Seann Wil...
# Name: Casts, Length: 4900, dtype: object

# %%
# Split the "Casts" column into "Director" and "Stars" columns
movie_DF[['Director', 'Stars']] = movie_DF['Casts'].str.split('|', n=1, expand=True)

# Remove the "Director:" and "Stars:" prefixes
movie_DF['Director'] = movie_DF['Director'].str.replace('Director:', '').str.strip()
movie_DF['Stars'] = movie_DF['Stars'].str.replace('Stars:', '').str.strip()

# Drop the original "Casts" column
movie_DF.drop(columns=['Casts'], inplace=True)

# %%
movie_DF
# Out:
#                                              Image Link
# 0     https://m.media-amazon.com/images/M/MV5BNDE3OD...  \
# 1     https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 2     https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 3     https://m.media-amazon.com/images/M/MV5BODQ0OW...
# 4     https://m.media-amazon.com/images/M/MV5BNGNhMD...
# ...                                                 ...
# 4895  https://m.media-amazon.com/images/M/MV5BMmZiYj...
# 4896  https://m.media-amazon.com/images/M/MV5BYTQyZG...
# 4897  https://m.media-amazon.com/images/M/MV5BMjIwNj...
# 4898  https://m.media-amazon.com/images/M/MV5BMTk3NT...
# 4899  https://m.media-amazon.com/images/M/MV5BMTY3MD...
#
#                  Name of movie Year of release Certificate Runtime (min)
# 0     The Shawshank Redemption            1994           A           142  \
# 1              The Dark Knight            2008          UA           152
# 2                    Inception            2010          UA           148
# 3                   Fight Club            1999           A           139
# 4                 Pulp Fiction            1994           A           154
# ...                        ...             ...         ...           ...
# 4895            House of Games            1987           U           102
# 4896                Umberto D.            1952         N/A            89
# 4897                 The Women        I) (2008          UA           114
# 4898       Aliens in the Attic            2009           U            86
# 4899             The Promotion            2008           R            86
#
#                           Genre Rating MetaScore      Votes   Grosses
# 0                         Drama    9.3        82  2,797,507   $28.34M  \
# 1          Action, Crime, Drama      9        84  2,778,489  $534.86M
# 2     Action, Adventure, Sci-Fi    8.8        74  2,466,695  $292.58M
# 3                         Drama    8.8        67  2,231,343   $37.03M
# 4                  Crime, Drama    8.9        95  2,145,836  $107.93M
# ...                         ...    ...       ...        ...       ...
# 4895            Crime, Thriller    7.2        78     23,437    $2.59M
# 4896                      Drama    8.2        92     27,291    $0.07M
# 4897              Comedy, Drama      5        27     22,540   $26.90M
# 4898  Adventure, Comedy, Family    5.4        42     23,653   $25.20M
# 4899                     Comedy    5.6        51     19,360    $0.41M
#
#                                             Description           Director
# 0     Over the course of several years, two convicts...     Frank Darabont  \
# 1     When the menace known as the Joker wreaks havo...  Christopher Nolan
# 2     A thief who steals corporate secrets through t...  Christopher Nolan
# 3     An insomniac office worker and a devil-may-car...      David Fincher
# 4     The lives of two mob hitmen, a boxer, a gangst...  Quentin Tarantino
# ...                                                 ...                ...
# 4895  A psychiatrist comes to the aid of a compulsiv...        David Mamet
# 4896  An elderly man and his dog struggle to survive...   Vittorio De Sica
# 4897  A wealthy New Yorker wrestles with the decisio...      Diane English
# 4898  A group of kids must protect their vacation ho...       John Schultz
# 4899  Two assistant managers of a corporate grocery ...       Steve Conrad
#
#                                                   Stars
# 0     Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# 1     Christian Bale, Heath Ledger, Aaron Eckhart, M...
# 2     Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
# 3     Brad Pitt, Edward Norton, Meat Loaf, Zach Grenier
# 4     John Travolta, Uma Thurman, Samuel L. Jackson,...
# ...                                                 ...
# 4895  Lindsay Crouse, Joe Mantegna, Mike Nussbaum, L...
# 4896  Carlo Battisti, Maria Pia Casilio, Lina Gennar...
# 4897  Meg Ryan, Eva Mendes, Annette Bening, Debra Me...
# 4898  Ashley Tisdale, Robert Hoffman, Carter Jenkins...
# 4899  Seann William Scott, John C. Reilly, Chris Con...
#
# [4900 rows x 13 columns]

# %%
movie_DF.to_excel('movie_data_part1.xlsx', index=False)

print("DataFrame saved to 'movie_data.xlsx'")
# Out:
# DataFrame saved to 'movie_data.xlsx'
